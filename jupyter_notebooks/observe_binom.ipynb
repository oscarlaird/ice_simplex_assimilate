# %% [markdown]
# ## observe_binom -- Bayesian update of $x_0$ given multidirichlet prior

# %%
from dirichlet_assimilate import shared_classes, examples, visualize, observe_binom
import importlib
def reload():
    for mod in (shared_classes, examples, visualize, observe_binom):
        importlib.reload(mod)

# %%
reload()
v = visualize.Visualisation(examples.h_bnd, figsize=(12, 4), log_scale=False)
v.show_class_dirichlet(examples.class_dirichlet_2, confidence=0.6)

# %%
examples.class_dirichlet_2.marg_cdf(0.1), examples.class_dirichlet_2.marg_cdf(0.35)
# Out:
# (0.18689527000000009, 0.8308731377734375)

# %%
reload()
v = visualize.Visualisation(examples.h_bnd, figsize=(12, 4), log_scale=False)
v.show_mixed_dirichlet(examples.mixed_dirichlet, confidence=0.9)

# %%
examples.mixed_dirichlet.marg_cdf(0.2)
# Out:
# 0.6176261653277123
