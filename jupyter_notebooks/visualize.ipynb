# %%
from importlib import reload
from dirichlet_assimilate import visualize
from dirichlet_assimilate import examples

# %%
v = visualize.Visualisation(examples.h_bnd, log_scale=False, figsize=(5,3))
v.show_raw_sample(examples.raw_sample)
v.ax.set_title('Raw Sample Area')
print('Raw Sample Area: ', examples.raw_sample.area)
# Out:
# Raw Sample Area:  [0.2  0.65 0.1 ]

# %%
v = visualize.Visualisation(examples.h_bnd, log_scale=False, figsize=(5,3))
v.show_raw_ensemble(examples.raw_ensemble)
v.ax.set_title('Raw Ensemble Area')
;
# Out:
# ''

# %%
v = visualize.Visualisation(examples.h_bnd, log_scale=False, figsize=(12,4))
v.show_sample(examples.sample)
v.ax.set_title('Sample')
print('Sample: ', examples.sample)
# Out:
# Sample:  [0.05  0.12  0.08  0.3   0.35  0.045 0.055]

# %%
v = visualize.Visualisation(examples.h_bnd, log_scale=False, figsize=(12,4))
v.show_ensemble(examples.ensemble)
v.ax.set_title('Ensemble');

# %%
v = visualize.Visualisation(examples.h_bnd, log_scale=False, figsize=(12, 4))
v.show_mixed_dirichlet_plus_samples(examples.ensemble, examples.mixed_dirichlet, confidence=0.6)
